# %%
import os

import pandas as pd

from stage2.mark_json import MarkJSON
from stage1.solution import solve

import warnings
warnings.filterwarnings("ignore")

# %%
def add_dataset(df, dataset, dataset_type):
    search_text_0 = 'АНАМНЕЗ'
    search_text_1 = 'ОБЪЕКТИВИЗИРОВАННАЯ ОЦЕНКА СОСТОЯНИЯ БОЛЬНОГО'
    search_text_2 = 'ФИЗИКАЛЬНЫЕ ПАРАМЕТРЫ'

    for path in os.listdir(dataset):
        if path [-1] != 'l':
            continue

        input_file = dataset + '/' + path
        answer_0 = solve(input_file, search_text_0)
        answer_1 = solve(input_file, search_text_1)
        answer_2 = solve(input_file, search_text_2)

        datum_id = int(path.split('_')[1])
        anamnesis = answer_0[0]['name']
        evaluation = answer_1[0]['name']
        parameters = answer_2[0]['name'] if len(answer_2) != 0 else None

        df = df.append(pd.Series({
            'id': datum_id, 
            'Anamnesis': anamnesis, 
            'Evaluation': evaluation, 
            'Parameters': parameters, 
            'Type': dataset_type, 
            'LabelsAnamnesis': None,
            'LabelsEvaluation': None,
            'LabelsParameters': None
        }), ignore_index=True)
    return df

# %%
df = pd.DataFrame(columns=['id', 'Anamnesis', 'Evaluation', 'Parameters', 'Type', 'LabelsAnamnesis', 'LabelsEvaluation', 'LabelsParameters'])

dataset = 'dataset/Эпикризы_отборочный_01_08_2023'
dataset_type = 'Отбор'
df = add_dataset(df, dataset, dataset_type)

dataset = 'dataset/Эпикризы_пример_19_05_2023'
dataset_type = 'Пример'
df = add_dataset(df, dataset, dataset_type)

# %%
df
# Out:
#              id                                          Anamnesis  \
# 0    1537696372  На учете не состояла, туберкулезом не болела. ...
# 1    2562228169  Ранее туберкулезом не болел. Изменения в легки...
# 2     391301814  При плановом ФГ исследовании от 23.07.20г. выя...
# 3     276785210  Туберкулезом ранее не болела. Контакт с больны...
# 4    2407504274  Анамнез жизни:\n\nРос и развивался по возрасту...
# ..          ...                                                ...
# 280  4147025371  Анамнез жизни\nПеренесенные и сопутствующие за...
# 281  3864859985  Особенности развития отсутствуют. Наследственн...
# 282  4006158698  Анамнез жизни\nРосла и развивалась без особенн...
# 283  3952594480  Анамнез заболевания \nБольным себя считает око...
# 284  3839924918  Анамнез жизни \n\nСопутствующие и перенесенные...
#
#                                             Evaluation Parameters    Type  \
# 0                                          Не выявлено       None   Отбор
# 1                                       Ну установлено       None   Отбор
# 2                                           Не указано       None   Отбор
# 3                                           Не указано       None   Отбор
# 4    Рост 180 см. Вес 120,0 кг. ИМТ 37,04 кг/м2. Са...       None   Отбор
# ..                                                 ...        ...     ...
# 280  Сознание ясное. Т тела 36,6 С. Гиперстенически...       None  Пример
# 281  Рост 175 см.Вес 80,0 кг.ИМТ 26,12 кг/м2.состоя...       None  Пример
# 282  Рост 169 см.Вес 80,0 кг.ИМТ 28,01 кг/м2.Темпер...       None  Пример
# 283  Рост 185 см. \nТ тела на момент осмотра 36.6 *...       None  Пример
# 284  Состояние средней степени тяжести. Температура...       None  Пример
#
#     LabelsAnamnesis LabelsEvaluation LabelsParameters
# 0              None             None             None
# 1              None             None             None
# 2              None             None             None
# 3              None             None             None
# 4              None             None             None
# ..              ...              ...              ...
# 280            None             None             None
# 281            None             None             None
# 282            None             None             None
# 283            None             None             None
# 284            None             None             None
#
# [285 rows x 8 columns]

# %%
for row in df.iterrows():
    name = row[1]['id']
    with open(f'dataset/for_labeling/{name}_anam.txt', 'w') as f:
        text = row[1]['Anamnesis']
        f.write(text.replace('\n', ' '))
    with open(f'dataset/for_labeling/{name}_eval.txt', 'w') as f:
        text = row[1]['Evaluation']
        f.write(text.replace('\n', ' '))

# %%
print(row[1]['Anamnesis'].replace('\n', '   '))
# Out:
# На учете не состояла, туберкулезом не болела. Предыдущее рентгенологическое исследование 09.09.20г. КТ ОГК  признаков очагового и инфильтративного характера на момент исследования достоверно не выявлено. Пересмотр в Королевском отделении 25.05.21г. в правом легком крупноочаговая тень с участком просветления, нельзя исключить туберкулёзную этиологию. Выраженные поствоспалительные изменения паренхимы обоих легких.    В апреле 2021г. у сына выявлен активный туберкулез легких. Выявлены изменения при рентгенологическом исследовании 21.05.21г. ( по поводу семейного туб. контакта с бациллярным пациентом с МЛУ) и дообследована. Где выявлены изменения в правой плевральной полости в виде гидроторакса. Рентгенологически- от 21.05.21г.- легкие без очаговых и инфильтративных теней. Отмечается затенение в нижних отделах правого легкого до уровня 4го ребра-? (свободная жидкость. плевральные наслоения). Взята на учет ГДУ0. УЗИ от 25.05.21г.- в правой плевральной полости свободная жидкость толщиной в боков синусе 74,5мм, в переднем 58,8мм, в заднем синусе 87,3 с выраженными плевральными наслоениями до 50мм в боков синусе.   Поступила в отделение обсервации 28.05.21 и 29.05.21 в 15.55 переведена легочно-хирургическое отделение.

# %%
answer_2
# Out:
# []
